# %% [markdown]
# # Python Basics

# %% [markdown]
# ### Datatypes

# %%
#This is how we define an string
"Hello world"

#This is how we define an integer
5

#This is how we define a float
2.0

#This is how boolean datatypes look like (They also have a numeric value associated to them: True=1, False=0)
True 
False

# %% [markdown]
# #### Strings

# %%
#This is how we define an string
"Hello world"

#There are some operations that we can perform with (to) strings, these are called string methods

"hello".upper() #Every letter is changed to upper case 
"hello".lower() #Every letter is changed to lower case 
"hello".capitalize() #The first letter is changed to upper case
"hello".count("o") #We can count the number of times a character appears
"hello".endswith("O") #Returns true if the string ends with the specified value
"hello".find("o") #Searches the string for a specified value and returns the position of where it was found
len("hello") #We get the length of the string

#We can also apply multiple methods at once

"hello".capitalize().count("O")

#Something important to say is that, when we apply two or various methods to the same string at once all of them will be executed, but the output 
#that will be shown to you is the one generated by the method that was applied at the end

"hello" + " " + "world" #Concatenation
"hello"*5 #Repeat a word 5 times

str(5) #Converter type

# %% [markdown]
# #### Integers and Floats

# %%
#This is how we define an integer
5

#This is how we define a float
2.0

2+3 #Sum 
9-5 #Subtraction
7*3 #Product
7/3 #Division
7%3 #This will give us the remainder of the division in this case 1 (Module)
7//3 #This will perfom the division ignoring any remainder, in this case the result will be 2
7**3 #Power

#The operations above can be performed also using floats

#We can also perform these operations with both types of numbers

20.3+8
52.12*9
78.9/3

#The result, as you can imagine will be a float

int(27.63) #Converter type for integer
float(78.25) #Converter type for float

#An important operation with numbers its comparison between them, the result of this operation will be a boolean value (True & False)

5==5 #equality
6!=5 #different of / is not
4 < 5 #less than
9 > 0 #greater than
10 >= 3 #greater than or equal to
8 <= 5 #less than or equal to

#We can go a bit further, and try to make some more complex comparisons by mixing the operators, 
#this can be done with the help of three reserved keywords

5==5 and 6<9
5>4 or 7<0
not True

# %% [markdown]
# ### Variables

# %%
#This is how we define a variable

variable=5
variable2="Ana"
variable3=6.3
variable4=True

#Note
#There are multiple ways to write the names of our variables (and functions too)

variable_2="Diego" #Snake case
VaribleTwo=False #Pascal case
variableTwo=1.23 #Camel case

#Use the one you like the most :) (but be consistent, always write names the same way)

# %% [markdown]
# ### Data structures

# %% [markdown]
# #### Lists

# %%
#This is how we define a list

l1=[] #Empty list
l2=["Diego","Maths",0,1,3.14159] #List with some elements

#Lists can be used to store any data that we want, from integers to booleans and even other lists.

#Inside a list the order matters, this is because every position at the list has an associated number to it, 
#called index of the element

l2[0] #Returns the element at the first position

#In the case that we want to have access to multiple elements by using their indexes we can use what is called the slice operator

l2[1:3] #This returns the elements with indexes 1 and 2 (The slicing operator excludes the element with index equals to the right limit)

#As well as with strings, there are some methods available for us to modify lists whenever we want, some of these methods are:

l1.append("You")
#This method will add the specified argument to the end of the list

l1.insert(1,"Me")
#This method will also add the specified argument to the list, but in this case it has
#to use two arguments, the first one is the index that we want to associate to the new
#element and the element itself

l1.index("element name")
#This method is used in order to look for the index associated to a certain element

l1.pop()
#This method is used to remove elements of a list, nevertheless there are two cases
#that we must consider when using this method, first is that in the case that we dont 
#specify which element we want to remove, the method will remove the last element of the
#list, otherwise it will remove the element that we state inside the method. Aditionally
#the .pop method gives us the option to store the value that it removed into a variable
#in other words it "returns" such value

l1.remove()
#This method, just like the previous one, is used for removing elements from a list,
#but unlike the previous one, this does need an argument to work, that is we need to
#specify the element that we want to remove. This method is not able to return the value
#that it removed from our list (unlike the .pop method)

l1.extend()
#This method is used for extending the content of our list, that is it adds more elements
#to our list, but the method does not work with any type of argument but just with iterable
#datatypes, that is: lists, strings, etc

l1.sort()
#The .sorted method is used to order the elements of an iterable datatye, that is: a list,
#string, etc. By order we mean that if we give it a word it will arrange the letters alphabetica-
#lly, if we give it a list with names it will do the same as previously. The argument that
#we pass to it has to be all elements of it of the same datatype

len(l1)
#This method will return the length of the list, that is how many elements it has

#Say that we have some predefined variables, we can unpack the content of a list by assigning to each element of it a variable

var1,var2,var3,var4,var5=l2

"element" in l2
#This method is used to check if a certain element belongs to a list or not, that is in return we will get a boolean value

list() #Converter type

# %% [markdown]
# #### Dictionaries

# %%
#This is how we define a dictionary

d1={}

#For each element in the dictionary we can identify two parts of it, 
#the key and the value. The way we access to elements inside the dictionary is by using the keys

dict2={"Math_subjects":["Algebra","Topology","Analysis"],"Numbers":[1,2,3,4],"Deserts":["Pay","Cake","Cookie"],"Name":"Diego"}

print(dict2.keys())
#This method will return all keys inside the dictionary

print(dict2.values())
#This method will return all values inside the dictionary

#If we want to add a new key-value pair we can do it as follows:
dict2["Physics_subjects"]=["Classical mechanics","Statistical physics","Quantum mechanics"]

del dict2["Math_subjects"]
#The del method is used for deleting a pair key value from our dictionary (this method is
#also available for lists: del l2[0])

dict() #Converter type

# %% [markdown]
# #### Tuples

# %%
#This is how we define a tuple

t1=()

#Once we have set what the content of a tuple is, we cannot modify it, that is a tuple is an inmutable datatype

t=(1,2,3)

t.count("element")
#This method is used to know how many times an element appears into the tuple

t.index("element")
#This method works the same way as with the list

"element" in t
#This method is used to check if a certain element belongs to a tuple or not, that is in return we will get a boolean value

var1,var2,var3=t

tuple() #Converter type

# %% [markdown]
# ### Control flow and loops

# %%
#Say that we want to develop a program such that if a certain condition is fulfilled then an operation can be executed, otherwise a different operation will be executed or no operations are executed at all. We can control operations this way by using 
#the if / elif / else keywords

name=input("Please enter a string:" )
if name == "Hello there":
    print("General Kenobi")
else:
    print("Who are you?")

#This simple example is just for the case that we have two alternatives: a certain condition is fulfilled or not, nevertheless we can 
#go further by adding multiple conditions, that is, the program needs to check the first condition, if such condition is not fulfilled, 
#then it can go and check a second condition, if such condition is not fulfilled then it must go to check a third condition and so on, 
# until finally if none of the conditions was fulfilled, then it must execute what was set in the else statement

name=input("Please enter your name:" )

if name == "Diego":
    print("Welcome to Cantor's Paradise"),

elif name == "Oz":
    print("I´ve seen you before"),

elif name == "George":
    print("Welcome home")
    
else:
    print("Hello you")

#Now, say that we need to perform a certain operation multiple times, also we want to set when to start and when to stop, we can do such thing by 
# using what is known as loops. There are two types of loops that we can use depending on how many times we want to perform an 
# operation, these are: for loops and while loops

#For loop 1

name=input("Enter your name: ")
for letter in name:
    print("Hello world")

#For loop 2

for i in range(10,16,2):
    print("hello world")

#While loop 1

i=0
while i<10:
    print("Hello world")
    i += 1

#While loop 2

i=0
while True:
    print("Hello world")
    i += 1
    if i == 10:
        break

#While loop 3

s = "Python"
for letter in s:
    if letter == "P":
        continue
    print(letter)
# Out:
# Who are u?

# %% [markdown]
# ### Functions

# %%
#A function is defined as a sequence of commands that executes a specific section of the code. 
#The sintax of a function is the following one...

def function_name(n,m,k):
    #operations to be excuted
    return 

function_name(1,2,3)

#In words, we start by using the reserved keyword “def”, next we set a name for the function, 
#after that we write parentheses and inside those we declare how many arguments does the function need to work. 
#There are two options for the arguments, this is: you can set default values for them, in such case even 
#if you do not pass values to the function it will use the values that we set before, 
#or we can leave them undefined and take into account that when calling the function we need to give it some values,
#finally we write the “return” statement, this will allow us to use the output of the function later.

def function_name2(a,b,c=9): #This is how we set a default value for an argument
    #operations to be executed
    return 

#Note

#In the case of the name function there are some limitations to consider: do not start by numbers, do not use reserved words, 
#set a descriptive name according to the operations it performs, set different names for the variables that you use, etc.

#Say that we have the following situation

def function(p):
    #Some operation involving the variable p
    return 
print(p)
x=10
print(x)

#If we were about to run this code, we would get an error in the first part of the code, in order to understand why this is happening 
#we have to make a distinction between types of variables, there are two of these. This types are: local variables and global variables. 
#For the case of local variables, they are just defined in a certain region of the code, in this case that region is inside the 
#function, so if we try to call this variable out of that region we will get an error due to the fact that is not defined out of there. 
#For the case of global variables they can be used everywhere in the code.

#Lambda functions, also known as anonymus functions, are one line functions that can handle any number of parameters that we want, 
#are assigned to a variable and dont need to use a return statement, their sintax is the following one:

my_first_lf=lambda x,y:  x**y
# Out:
# 5
