# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
#Open the file and read it

df=pd.read_csv("Sleep_health_and_lifestyle_dataset.csv")

# %%
#Getting the dimensions of the dataframe

df.shape
# Out:
# (374, 13)

# %%
#Getting column names

df.columns
# Out:
# Index(['person id', 'gender', 'age', 'occupation', 'sleep duration',
#        'quality of sleep', 'physical activity level', 'stress level',
#        'bmi category', 'blood pressure', 'heart rate', 'daily steps',
#        'sleep disorder'],
#       dtype='object')

# %%
#Get the first n rows

df.head(20)
# Out:
#     Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0           1    Male   27     Software Engineer             6.1
# 1           2    Male   28                Doctor             6.2
# 2           3    Male   28                Doctor             6.2
# 3           4    Male   28  Sales Representative             5.9
# 4           5    Male   28  Sales Representative             5.9
# 5           6    Male   28     Software Engineer             5.9
# 6           7    Male   29               Teacher             6.3
# 7           8    Male   29                Doctor             7.8
# 8           9    Male   29                Doctor             7.8
# 9          10    Male   29                Doctor             7.8
# 10         11    Male   29                Doctor             6.1
# 11         12    Male   29                Doctor             7.8
# 12         13    Male   29                Doctor             6.1
# ...

# %%
#Getting the last n rows

df.tail(20)
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 354        355  Female   58      Nurse             8.0                 9
# 355        356  Female   58      Nurse             8.0                 9
# 356        357  Female   58      Nurse             8.0                 9
# 357        358  Female   58      Nurse             8.0                 9
# 358        359  Female   59      Nurse             8.0                 9
# 359        360  Female   59      Nurse             8.1                 9
# 360        361  Female   59      Nurse             8.2                 9
# 361        362  Female   59      Nurse             8.2                 9
# 362        363  Female   59      Nurse             8.2                 9
# 363        364  Female   59      Nurse             8.2                 9
# 364        365  Female   59      Nurse             8.0                 9
# 365        366  Female   59      Nurse             8.0                 9
# ...

# %%
#Getting the NumPy representation of the data

df.to_numpy
# Out:
# <bound method DataFrame.to_numpy of      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# ...

# %%
#Gets the index used for the rows

df.index
# Out:
# RangeIndex(start=0, stop=374, step=1)

# %%
#Gets a quick summary of the data

df.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
#Gets more information about the data

df.info
# Out:
# <bound method DataFrame.info of      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# ...

# %%
#Counts the values in a dataframe or a column

df.value_counts()
# Out:
# Person ID  Gender  Age  Occupation         Sleep Duration  Quality of Sleep  Physical Activity Level  Stress Level  BMI Category  Blood Pressure  Heart Rate  Daily Steps  Sleep Disorder
# 1          Male    27   Software Engineer  6.1             6                 42                       6             Overweight    126/83          77          4200         None              1
# 247        Male    44   Salesperson        6.3             6                 45                       7             Overweight    130/85          72          6000         Insomnia          1
# 256        Female  45   Teacher            6.5             7                 45                       4             Overweight    135/90          65          6000         Insomnia          1
# 255        Female  45   Teacher            6.5             7                 45                       4             Overweight    135/90          65          6000         Insomnia          1
# ...

# %%
df["Occupation"].value_counts()
# Out:
# Nurse                   73
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Software Engineer        4
# Scientist                4
# Sales Representative     2
# Manager                  1
# Name: Occupation, dtype: int64

# %%
#Gets the unique values in a column

df["Occupation"].unique()
# Out:
# array(['Software Engineer', 'Doctor', 'Sales Representative', 'Teacher',
#        'Nurse', 'Engineer', 'Accountant', 'Scientist', 'Lawyer',
#        'Salesperson', 'Manager'], dtype=object)

# %%
#Gets the count of unique values in a column

df["Occupation"].nunique()
# Out:
# 11

# %%
#Transposing our data

df.T
# Out:
#                                        0       1       2    \
# Person ID                                1       2       3
# Gender                                Male    Male    Male
# Age                                     27      28      28
# Occupation               Software Engineer  Doctor  Doctor
# Sleep Duration                         6.1     6.2     6.2
# Quality of Sleep                         6       6       6
# Physical Activity Level                 42      60      60
# Stress Level                             6       8       8
# BMI Category                    Overweight  Normal  Normal
# Blood Pressure                      126/83  125/80  125/80
# Heart Rate                              77      75      75
# Daily Steps                           4200   10000   10000
# Sleep Disorder                        None    None    None
#
#                                           3                     4    \
# ...

# %%
#Sorting index according to the rows

df.sort_index(axis=0,ascending=True)
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
#Sorting index according to the columns

df.sort_index(axis=1,ascending=True)
# Out:
#      Age BMI Category Blood Pressure  Daily Steps  Gender  Heart Rate  \
# 0     27   Overweight         126/83         4200    Male          77
# 1     28       Normal         125/80        10000    Male          75
# 2     28       Normal         125/80        10000    Male          75
# 3     28        Obese         140/90         3000    Male          85
# 4     28        Obese         140/90         3000    Male          85
# ..   ...          ...            ...          ...     ...         ...
# 369   59   Overweight         140/95         7000  Female          68
# 370   59   Overweight         140/95         7000  Female          68
# 371   59   Overweight         140/95         7000  Female          68
# 372   59   Overweight         140/95         7000  Female          68
# 373   59   Overweight         140/95         7000  Female          68
#
#                Occupation  Person ID  Physical Activity Level  \
# 0       Software Engineer          1                       42
# ...

# %%
#Sorting our data according to the values on the column Age

df.sort_values("Age")
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 359        360  Female   59                 Nurse             8.1
# 358        359  Female   59                 Nurse             8.0
# 372        373  Female   59                 Nurse             8.1
# 364        365  Female   59                 Nurse             8.0
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
#Selecting a single column

df["Age"]
# Out:
# 0      27
# 1      28
# 2      28
# 3      28
# 4      28
#        ..
# 369    59
# 370    59
# 371    59
# 372    59
# 373    59
# Name: Age, Length: 374, dtype: int64

# %%
#Selecting multiple columns

df[["Age","Occupation"]]
# Out:
#      Age            Occupation
# 0     27     Software Engineer
# 1     28                Doctor
# 2     28                Doctor
# 3     28  Sales Representative
# 4     28  Sales Representative
# ..   ...                   ...
# 369   59                 Nurse
# 370   59                 Nurse
# 371   59                 Nurse
# 372   59                 Nurse
# 373   59                 Nurse
#
# [374 rows x 2 columns]

# %%
#Alternative way of selection

df.Occupation
# Out:
# 0         Software Engineer
# 1                    Doctor
# 2                    Doctor
# 3      Sales Representative
# 4      Sales Representative
#                ...
# 369                   Nurse
# 370                   Nurse
# 371                   Nurse
# 372                   Nurse
# 373                   Nurse
# Name: Occupation, Length: 374, dtype: object

# %%
#Selecting rows (use the slice operator)

df[:3]
# Out:
#    Person ID Gender  Age         Occupation  Sleep Duration  Quality of Sleep  \
# 0          1   Male   27  Software Engineer             6.1                 6
# 1          2   Male   28             Doctor             6.2                 6
# 2          3   Male   28             Doctor             6.2                 6
#
#    Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 0                       42             6   Overweight         126/83
# 1                       60             8       Normal         125/80
# 2                       60             8       Normal         125/80
#
#    Heart Rate  Daily Steps Sleep Disorder
# 0          77         4200           None
# 1          75        10000           None
# 2          75        10000           None

# %%
#Selecting rows (use the loc method)

df.loc[:5,"Age"]
# Out:
# 0    27
# 1    28
# 2    28
# 3    28
# 4    28
# 5    28
# Name: Age, dtype: int64

# %%
#Selecting rows (use the iloc method)

df.iloc[:5,-1]
# Out:
# 0           None
# 1           None
# 2           None
# 3    Sleep Apnea
# 4    Sleep Apnea
# Name: Sleep Disorder, dtype: object

# %%
#Filtering selection

df[df["Age"]>30]
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 32          33  Female   31      Nurse             7.9                 8
# 33          34    Male   31     Doctor             6.1                 6
# 34          35    Male   31     Doctor             7.7                 7
# 35          36    Male   31     Doctor             6.1                 6
# 36          37    Male   31     Doctor             6.1                 6
# ..         ...     ...  ...        ...             ...               ...
# 369        370  Female   59      Nurse             8.1                 9
# 370        371  Female   59      Nurse             8.0                 9
# 371        372  Female   59      Nurse             8.1                 9
# 372        373  Female   59      Nurse             8.1                 9
# 373        374  Female   59      Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level   BMI Category Blood Pressure  \
# ...

# %%
#Filtering selection (using the isin method)

df[df["Gender"].isin(["Male"])]
# Out:
#      Person ID Gender  Age            Occupation  Sleep Duration  \
# 0            1   Male   27     Software Engineer             6.1
# 1            2   Male   28                Doctor             6.2
# 2            3   Male   28                Doctor             6.2
# 3            4   Male   28  Sales Representative             5.9
# 4            5   Male   28  Sales Representative             5.9
# ..         ...    ...  ...                   ...             ...
# 249        250   Male   44           Salesperson             6.5
# 264        265   Male   48                Doctor             7.3
# 266        267   Male   48                Doctor             7.3
# 276        277   Male   49                Doctor             8.1
# 277        278   Male   49                Doctor             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
#Setting a new column

df["New_column"]="" #This adds an empty column
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
#Dropping a column and saving changes

df.drop(columns={"New_column"},inplace=True)

# %%
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
#Renaming a column and saving changes

df.rename(columns={"Age":"Age"},inplace=True)

# %%
#Changing the values in a column

df["Age"]=0

# %%
#Changing a specific value

df.loc[1,1]=0

# %%
#Identifying missing values

df.isna()
# Out:
#      Person ID  Gender    Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0        False   False  False       False           False             False
# 1        False   False  False       False           False             False
# 2        False   False  False       False           False             False
# 3        False   False  False       False           False             False
# 4        False   False  False       False           False             False
# ..         ...     ...    ...         ...             ...               ...
# 369      False   False  False       False           False             False
# 370      False   False  False       False           False             False
# 371      False   False  False       False           False             False
# 372      False   False  False       False           False             False
# 373      False   False  False       False           False             False
#
# ...

# %%
#Dropping missing values and saving changes

df.dropna(inplace=True)

# %%
#Filling missing values and saving changes

df.fillna(1,inplace=True)

# %%
#Basic statistics

df["Age"].mean() #Mean
df["Age"].median() #Median
df["Age"].std() #Standard deviation
df["Age"].mode() #Mode
# Out:
# 0    43
# Name: Age, dtype: int64

# %%
#String methods

df.columns=df.columns.str.lower()

# %%
df.head(3)
# Out:
#    person id gender  age         occupation  sleep duration  quality of sleep  \
# 0          1   Male   27  Software Engineer             6.1                 6
# 1          2   Male   28             Doctor             6.2                 6
# 2          3   Male   28             Doctor             6.2                 6
#
#    physical activity level  stress level bmi category blood pressure  \
# 0                       42             6   Overweight         126/83
# 1                       60             8       Normal         125/80
# 2                       60             8       Normal         125/80
#
#    heart rate  daily steps sleep disorder
# 0          77         4200           None
# 1          75        10000           None
# 2          75        10000           None

# %%
df.columns=df.columns.str.capitalize()

# %%
df.head(3)
# Out:
#    Person id Gender  Age         Occupation  Sleep duration  Quality of sleep  \
# 0          1   Male   27  Software Engineer             6.1                 6
# 1          2   Male   28             Doctor             6.2                 6
# 2          3   Male   28             Doctor             6.2                 6
#
#    Physical activity level  Stress level Bmi category Blood pressure  \
# 0                       42             6   Overweight         126/83
# 1                       60             8       Normal         125/80
# 2                       60             8       Normal         125/80
#
#    Heart rate  Daily steps Sleep disorder
# 0          77         4200           None
# 1          75        10000           None
# 2          75        10000           None

# %%
#Grouping data

df.groupby(["Gender"])["Quality of sleep"].sum()
# Out:
# Gender
# Female    1418
# Male      1317
# Name: Quality of sleep, dtype: int64
